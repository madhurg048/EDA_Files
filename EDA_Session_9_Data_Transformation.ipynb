# %% [markdown]
# - log tansformation
#
# - exponential transformation
#
# - reciprocal transformation
#
# - sqrt transformation
#
# - power transformation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exp_data = np.random.exponential(size= 1000)
exp_data
# This will give the 1000 random sample 
# It follows exponential diustribution
# Out:
# array([6.13616883e-01, 1.89887350e+00, 1.96653859e+00, 9.93593507e-01,
#        3.62202536e+00, 5.50882922e-01, 4.40838754e-01, 3.61632292e-01,
#        2.92852742e-02, 9.67544816e-01, 3.27140755e+00, 9.21942636e-01,
#        2.00822368e+00, 3.35103073e-01, 1.75513417e+00, 3.48437026e+00,
#        8.50491444e-01, 9.07293550e-01, 2.48590768e-01, 2.90850851e+00,
#        1.03696659e+00, 9.82377074e-01, 2.36584312e+00, 4.12494331e-02,
#        1.78053435e+00, 1.30683072e+00, 1.12671767e+00, 2.65675874e+00,
#        8.10362057e-02, 1.02388246e-01, 2.12114265e-01, 3.97370251e-01,
#        2.85032296e-01, 4.13655167e-02, 1.89575095e+00, 4.32559906e-01,
#        1.66891797e+00, 2.65802409e-01, 1.15401661e+00, 3.68892755e-01,
#        5.03270457e+00, 6.77637839e-01, 1.05262164e+00, 7.39252262e-01,
#        3.34899353e-01, 1.70602928e+00, 1.92611895e-01, 1.21637440e-01,
#        6.31052111e-01, 1.79993031e+00, 1.17338281e-01, 2.41634690e+00,
# ...

# %%
plt.hist(exp_data, bins = 20, label="Exp_data")
plt.show()

# %%
nor_data = np.random.normal(size= 1000)
nor_data
# Out:
# array([ 2.17454546e-01,  1.51884102e-01, -7.71512187e-01, -3.04649119e+00,
#         7.48612007e-01,  1.55593912e-01, -1.67119100e+00,  3.85014863e-02,
#        -7.21334894e-01,  9.91741082e-02, -5.38643408e-01, -8.87896530e-01,
#        -1.41404975e-01,  7.41047925e-01, -1.09504662e+00, -7.30847633e-02,
#        -7.69818311e-01,  1.24572943e+00,  1.17535872e+00, -3.45262183e-01,
#        -3.63496558e-01,  1.18048547e+00, -8.17412505e-01,  2.70773703e-01,
#        -1.22531469e-01,  4.32658406e-01, -1.16133002e+00, -1.02070571e+00,
#        -3.56537639e-03,  1.02921797e+00,  1.83127636e+00,  7.05394428e-01,
#        -1.12540512e+00,  9.40863051e-01, -4.17461743e-01,  1.91723863e-01,
#         5.14806418e-01, -3.87731385e-01, -1.63743152e+00,  1.51069397e+00,
#         6.04192191e-01, -5.78767052e-01,  6.14411138e-02,  9.33667228e-01,
#         5.22985360e-01, -5.25164608e-01,  5.17352703e-03,  1.92744695e+00,
# ...

# %%
plt.hist(nor_data, bins = 20, label="Exp_data")
plt.show()

# %% [markdown]
# **Main goal is exp_data to nor_data**

# %% [markdown]
# **Log Transformation**

# %%
x = 20
np.log(20)
# Out:
# 2.995732273553991

# %%
log_data = np.log(exp_data)

# %%
plt.hist(log_data)
plt.show()

# %%
plt.hist(log_data)
plt.hist(exp_data)
plt.show()

# %%
x = 25
np.sqrt(x)
# Out:
# 5.0

# %%
x =10 
1/x
# Out:
# 0.1

# %%
x = 5
np.exp(x)
# Out:
# 148.4131591025766

# %%
path = r"C:\Users\madhu\OneDrive\Documents\Naresh IT\Data files\Visadataset.csv"
visa_df = pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_column = visa_df.select_dtypes(include=object).columns
num_column = visa_df.select_dtypes(exclude=object).columns
cat_column
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss =StandardScaler()

# %%
#series data is 1D array
visa_df['prevailing_wage'].values
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
np.ndim(np.array([[[1,2,3]]]))
# Out:
# 3

# %%
np
# Out:
# <module 'numpy' from 'C:\\Users\\madhu\\anaconda3\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
np.ndim(visa_df[['prevailing_wage']])
# Out:
# 2

# %% [markdown]
# **Power Transformer**

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
transform_wage_data = pt.fit_transform(visa_df[['prevailing_wage']])
transform_wage_data
# Out:
# array([[-1.93915141],
#        [ 0.34503309],
#        [ 0.91555926],
#        ...,
#        [ 1.21170443],
#        [ 0.38794165],
#        [ 0.13879466]])

# %%
# ye jhonson method8

# box cox method

# %%
from sklearn.preprocessing import power_transform
pt=power_transform(visa_df[['prevailing_wage']])
pt
# Out:
# array([[-1.93915141],
#        [ 0.34503309],
#        [ 0.91555926],
#        ...,
#        [ 1.21170443],
#        [ 0.38794165],
#        [ 0.13879466]])

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(visa_df['prevailing_wage'],bins = 20)
plt.subplot(1,2,2)
plt.hist(transform_wage_data, bins =20)
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.boxplot(visa_df['prevailing_wage'],vert = False)
plt.subplot(1,2,2)
plt.boxplot(transform_wage_data,vert = False)
plt.show()

# %% [markdown]
# - Transformation affect the outliers of the data
#
#     - Log Transformation
#
#     - Exp Transformation
#
#     - Reciprocal Transformation
#
#     - Sqrt Transformation
#
#     - Power Transformation
#
# - Scaling of the data
#
#     - Z - Scale
#
#     - Min Max Scale
#
# - So that's why based on problem statement
#
# - Two Approaches
#
#     - First Treat the outliers then do Transformation or scaling
#
#     - Second transform or scale the data, then work on outliers
#
#         - In this case if you found any outliers it is called as **influential outliers**
#
# - we cannot say which is the best method it completely depends on problem to problem
